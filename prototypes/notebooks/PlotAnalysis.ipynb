# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("combine.csv")

# %%
df.head()
# Out:
#          Date  Close   ma_5     ma_10     ma_20     ma_30     ma_60    ma_180  \
# 0  2012-01-03   5.32  4.975  4.975000  4.975000  4.975000  4.975000  4.975000
# 1  2012-01-04   5.57  5.094  5.094000  5.094000  5.094000  5.094000  5.094000
# 2  2012-01-05   6.65  5.508  5.353333  5.353333  5.353333  5.353333  5.353333
# 3  2012-01-06   6.90  5.888  5.574286  5.574286  5.574286  5.574286  5.574286
# 4  2012-01-09   6.90  6.850  5.972000  5.972000  5.972000  5.972000  5.972000
#
#      ma_240    ma_360  ...  Nasdaq_diff  SP500_diff  INDU_diff  Oil_diff  \
# 0  4.975000  4.975000  ...         0.00        0.00       0.00    0.0000
# 1  5.094000  5.094000  ...        -0.36        0.24      21.04    0.8793
# 2  5.353333  5.353333  ...        21.50        3.76      -2.72    0.0000
# 3  5.574286  5.574286  ...         4.36       -3.25     -55.78    0.0000
# 4  5.972000  5.972000  ...         2.34        2.89      32.77    0.0000
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Close', 'ma_5', 'ma_10', 'ma_20', 'ma_30', 'ma_60', 'ma_180',
#        'ma_240', 'ma_360', 'Gold', 'Nasdaq_Comp', 'SP500', 'INDU', 'Oil',
#        'Btc_diff', 'Gold_diff', 'Nasdaq_diff', 'SP500_diff', 'INDU_diff',
#        'Oil_diff', 'Btc_diffpct', 'Gold_diffpct', 'Nasdaq_diffpct',
#        'SP500_diffpct', 'INDU_diffpct', 'Oil_diffpct'],
#       dtype='object')

# %%
df_ma = df.iloc[0:60]
df_ma.plot.line(x="Date", y=['Close', 'ma_5', 'ma_10', 'ma_20', 'ma_30', 'ma_60', 'ma_180', 'ma_240', 'ma_360'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_diff = df.iloc[0:60]
df_diff.plot.line(x="Date", y=['Btc_diffpct', 'Gold_diffpct', 'Nasdaq_diffpct', 'SP500_diffpct', 'INDU_diffpct', 'Oil_diffpct'])
# Out:
# <AxesSubplot:xlabel='Date'>
